# %%
import time
import requests
import random
import pandas as pd
from bs4 import BeautifulSoup
from pymongo import MongoClient
from datetime import date, timedelta

# %%
def allsundays(year):
    d = date(year, 1, 1)
    d += timedelta(days = 6 - d.weekday())
    while d.year == year:
        yield d
        d += timedelta(days = 7)
        
def create_df(timestamps):
    df = pd.DataFrame()
    for t in timestamps:
        print('fetching data from', t)
        time.sleep(random.uniform(1, 3))
        quote_page = 'https://coinmarketcap.com/historical/'+t
        page = requests.get(quote_page)
        second = BeautifulSoup(page.content,"lxml")
        table = second.find('div', class_ = 'table-responsive')
        while table is None:
            page = requests.get(quote_page)
            second = BeautifulSoup(page.content,"lxml")
            table = second.find('div', class_ = 'table-responsive')
        all_data = []
        for row in table.findAll('tr'):
            list_of_cells = []
            for cell in row.findAll(["th","td"]):
                text = cell.text
                list_of_cells.append(text)
            list_of_cells.append(t)
            all_data.append(list_of_cells)
        temp = pd.DataFrame(all_data[1:])
        df = df.append(temp, ignore_index=True)
        print('job done!')
    df = df.replace('\n','', regex=True)
    df.columns = ['#', 'Name', 'Symbol', 'MktCap', 'Price', 'Circulating Supply', 'Volume (24h)','% 1h', '% 24h', '% 7d', 'delete', 'Date']
    df.MktCap = df.MktCap.str.replace(',', '').str.replace('$', '')
    df = df.drop('delete', axis=1)
    df = df.set_index('Date')
    return df

# %%
timestamps = []

# %%
for d in allsundays(2018):
    timestamps.append(d.strftime("%Y, %m, %d").replace(',','').replace(' ', ''))

# %%
df = create_df(timestamps)
# Out:
# fetching data from 20180107
# job done!
# fetching data from 20180114
# job done!

# %%
df
# Out:
#              #                 Name  Symbol        MktCap      Price  \
# Date
# 20180107     1           BTCBitcoin     BTC  276634593973  $16477.59
# 20180107     2               XRPXRP     XRP  130853590979      $3.38
# 20180107     3          ETHEthereum     ETH  111670506535   $1153.17
# 20180107     4      BCHBitcoin Cash     BCH   47096266035   $2786.88
# 20180107     5           ADACardano     ADA   26147944638      $1.01
# 20180107     6               XEMNEM     XEM   16584480284      $1.84
# 20180107     7          LTCLitecoin     LTC   15766509797    $288.45
# 20180107     8              TRXTRON     TRX   13126926720  $0.199655
# 20180107     9           XLMStellar     XLM   12508160612  $0.699645
# 20180107    10            MIOTAIOTA   MIOTA   11314255332      $4.07
# 20180107    11             DASHDash    DASH   10032309522   $1285.43
# 20180107    12               EOSEOS     EOS    7375464637     $12.52
# 20180107    13            XMRMonero     XMR    7154342256    $459.33
# 20180107    14               NEONEO     NEO    6657898941    $102.43
# 20180107    15             QTUMQtum    QTUM    6328877478     $85.77
# 20180107    16      BTGBitcoin Gold     BTG    5062943204    $302.25
# 20180107    17  ETCEthereum Classic     ETC    4036612036     $40.79
# 20180107    18              LSKLisk     LSK    3983197348     $34.11
# 20180107    19              ICXICON     ICX    3754430021      $9.92
# 20180107    20             NANONano    NANO    3532219277     $26.51
# 20180107    21            SCSiacoin      SC    2878259194  $0.091676
# 20180107    22          BCNBytecoin     BCN    2822416228  $0.015402
# 20180107    23             ZECZcash     ZEC    2649258219    $880.76
# 20180107    24             XVGVerge     XVG    2640574738  $0.181957
# 20180107    25           OMGOmiseGO     OMG    2491049411     $24.41
# 20180107    26        BCCBitConnect     BCC    2327791324    $376.96
# 20180107    27         BTSBitShares     BTS    2130259352  $0.817190
# 20180107    28          PPTPopulous     PPT    2058818350     $55.64
# 20180107    29         DOGEDogecoin    DOGE    1925382104  $0.017088
# 20180107    30         DCNDentacoin     DCN    1898695867  $0.005839
# ...        ...                  ...     ...           ...        ...
# 20180114  1367            CMECashme     CME             ?  $0.000414
# 20180114  1368          SFESafeCoin     SFE             ?  $0.000414
# 20180114  1369         GOLFGolfcoin    GOLF             ?  $0.000414
# 20180114  1370           TEAMTeamUp    TEAM             ?  $0.000414
# 20180114  1371  XSTCSafe Trade Coin    XSTC             ?  $0.000414
# 20180114  1372          TCOINT-coin   TCOIN             ?  $0.000414
# 20180114  1373      IFCInfinitecoin     IFC             ?  $0.000363
# 20180114  1374       COUPECoupecoin   COUPE             ?  $0.000278
# 20180114  1375       FFCFireFlyCoin     FFC             ?  $0.000276
# 20180114  1376            UNCUNCoin     UNC             ?  $0.000276
# 20180114  1377             RCNRcoin     RCN             ?  $0.000276
# 20180114  1378       MONEYMoneyCoin   MONEY             ?  $0.000276
# 20180114  1379           LEPENLePen   LEPEN             ?  $0.000276
# 20180114  1380           BITOKBitok   BITOK             ?  $0.000276
# 20180114  1381          XTDXTD Coin     XTD             ?  $0.000276
# 20180114  1382         NAMONamoCoin    NAMO             ?  $0.000276
# 20180114  1383         UAHPAYUAHPay  UAHPAY             ?  $0.000258
# 20180114  1384          PRNIronCoin     PRN             ?  $0.000235
# 20180114  1385       KARMAKarmacoin   KARMA             ?  $0.000138
# 20180114  1386          PAYPPayPeer    PAYP             ?  $0.000138
# 20180114  1387           YESYescoin     YES             ?  $0.000138
# 20180114  1388       KASHHKashhCoin   KASHH             ?  $0.000138
# 20180114  1389       TURBOTurboCoin   TURBO             ?  $0.000138
# 20180114  1390        MENPeopleCoin     MEN             ?  $0.000138
# 20180114  1391        EXRNEXRNchain    EXRN             ?  $0.000089
# 20180114  1392          PCNPeepCoin     PCN             ?  $0.000051
# 20180114  1393         TERATeraCoin    TERA             ?  $0.000049
# 20180114  1394        FUDDDimonCoin    FUDD             ?  $0.000031
# 20180114  1395       FLAPFlappyCoin    FLAP             ?  $0.000015
# 20180114  1396      SHNDStrongHands    SHND             ?  $0.000012
#
#          Circulating Supply     Volume (24h)     % 1h    % 24h     % 7d
# Date
# 20180107         16,788,537  $15,865,964,544   -0.90%   -5.80%   17.66%
# 20180107    38,739,144,847*   $2,395,150,848    0.47%    8.19%   48.45%
# 20180107         96,837,992   $5,569,883,136    2.82%   10.26%   53.07%
# 20180107         16,899,275   $1,444,779,648   -1.12%    0.55%   10.41%
# 20180107     25,927,070,538     $226,066,848   -0.75%   -1.20%   39.79%
# 20180107     8,999,999,999*     $123,173,224    0.66%   11.81%   77.79%
# 20180107         54,659,308   $1,055,404,160   -0.84%   -3.21%   25.03%
# 20180107     65,748,192,475   $1,750,351,744    9.57%   15.90%  346.68%
# 20180107    17,877,858,808*     $347,556,672    1.13%   -0.75%   84.17%
# 20180107     2,779,530,283*     $249,833,360   -1.92%    2.58%   13.87%
# 20180107          7,804,616     $230,575,920    0.06%    0.92%   21.89%
# 20180107       589,006,616*     $781,496,768   -0.79%    2.13%   43.27%
# 20180107         15,575,558     $262,443,472    0.48%    1.59%   32.02%
# 20180107        65,000,000*     $196,621,328   -0.32%    2.37%   35.56%
# 20180107        73,791,156*   $1,707,138,944   -1.07%   -6.07%   38.56%
# 20180107         16,751,024     $203,683,648   -1.88%    2.74%   15.12%
# 20180107         98,953,271     $423,276,192   -0.23%    6.26%   37.64%
# 20180107       116,765,592*     $209,374,160    0.88%    8.11%   67.30%
# 20180107       378,545,005*     $283,778,048    1.74%   27.63%   85.08%
# 20180107       133,248,289*      $50,381,368   -4.05%   -9.24%   24.35%
# 20180107     31,396,146,174     $195,630,752    0.40%   -3.09%  204.12%
# 20180107    183,253,534,612      $31,409,674    2.52%   -7.81%  163.66%
# 20180107          3,007,919     $542,981,376    0.14%   17.57%   74.32%
# 20180107     14,512,056,800     $252,850,624    0.93%    3.37%  -14.42%
# 20180107       102,042,552*     $250,608,592    1.51%   25.20%   25.83%
# 20180107          6,175,179      $21,804,920   -2.13%  -15.74%  -10.06%
# 20180107     2,606,810,000*      $44,895,204    0.51%   -3.07%   21.27%
# 20180107        37,004,027*      $10,494,684   -5.24%   30.66%   35.38%
# 20180107    112,676,542,843     $288,184,256    1.58%   13.94%   91.61%
# 20180107   325,190,215,376*      $40,995,908   11.05%  159.08%  927.68%
# ...                     ...              ...      ...      ...      ...
# 20180114                  ?          Low Vol    0.89%   43.81%   38.50%
# 20180114                  ?          $19,312   24.68%   33.05%   20.37%
# 20180114                 ?*           $6,084    0.89%   -2.36%   38.73%
# 20180114                 ?*          Low Vol    0.90%   -4.12%  -34.17%
# 20180114                 ?*           $1,940    0.90%    3.33%  -27.13%
# 20180114                  ?           $1,669   51.33%  -26.83%   65.83%
# 20180114                  ?       $1,004,346   43.14%   -2.38%  -61.01%
# 20180114                 ?*         $161,469    1.79%  -28.13%   83.56%
# 20180114                  ?          Low Vol    0.90%   -4.12%  -18.16%
# 20180114                 ?*          $97,789   56.82%   20.29%   71.02%
# 20180114                  ?           $1,889    0.90%   50.91%   71.02%
# 20180114                  ?          Low Vol  101.78%   -4.13%  -31.55%
# 20180114                 ?*             $659    0.90%   60.50%    0.04%
# 20180114                 ?*           $7,475    8.65%   -4.10%   71.04%
# 20180114                  ?           $2,908    0.90%  -25.76%  -13.60%
# 20180114                  ?          Low Vol    0.90%   -4.12%  -35.32%
# 20180114                 ?*           $7,419   -2.64%   33.03%   48.30%
# 20180114                 ?*          $57,948   24.11%    1.19%  200.23%
# 20180114                  ?           $3,268    1.00%   -4.12%  -14.48%
# 20180114                  ?           $1,859  -24.32%   -4.13%  -69.49%
# 20180114                  ?          Low Vol    0.90%   -4.12%  -14.49%
# 20180114                 ?*          Low Vol    0.90%   -4.12%  -14.49%
# 20180114                 ?*           $4,765  -29.33%  -56.21%  -56.03%
# 20180114                  ?          Low Vol    0.89%   -4.13%  -14.49%
# 20180114                 ?*          $58,879    2.41%  -20.89%  -41.91%
# 20180114                 ?*          $25,373   -3.02%   -2.37%  -25.36%
# 20180114                  ?           $1,841    0.98%   43.55%  -69.84%
# 20180114                 ?*          $11,472  -19.89%  -28.78%  -47.52%
# 20180114                  ?             $747    2.83%  -21.46%  -40.12%
# 20180114                  ?         $909,796    2.01%  -57.21%  132.92%
#
# [2755 rows x 10 columns]

# %%
df.loc['20190201'][0:10]
# Out:
#            #             Name Symbol       MktCap      Price  \
# Date
# 20190201   1       BTCBitcoin    BTC  61088747491   $3487.95
# 20190201   2           XRPXRP    XRP  12699646520  $0.308517
# 20190201   3      ETHEthereum    ETH  11263815610    $107.61
# 20190201   4           EOSEOS    EOS   2120782711      $2.34
# 20190201   5  BCHBitcoin Cash    BCH   2051265822    $116.56
# 20190201   6       USDTTether   USDT   2033605783      $1.01
# 20190201   7      LTCLitecoin    LTC   1978856939     $32.83
# 20190201   8          TRXTRON    TRX   1751407526  $0.026271
# 20190201   9       XLMStellar    XLM   1602022106  $0.083580
# 20190201  10    BSVBitcoin SV    BSV   1132412159     $64.35
#
#          Circulating Supply    Volume (24h)    % 1h   % 24h     % 7d
# Date
# 20190201         17,514,250  $5,422,926,707  -0.23%   0.69%   -3.06%
# 20190201    41,163,466,448*    $564,486,615   0.11%  -0.47%   -2.24%
# 20190201        104,672,781  $2,541,271,519  -0.28%   0.50%   -7.49%
# 20190201       906,245,118*    $648,027,079  -0.33%   0.73%   -4.54%
# 20190201         17,598,863    $246,917,441  -0.22%   1.38%   -8.75%
# 20190201     2,020,855,917*  $3,949,396,927  -0.01%  -0.12%   -0.32%
# 20190201         60,281,237    $825,977,656  -0.84%   3.58%    0.12%
# 20190201     66,666,432,032    $266,911,186   0.00%   3.51%   -1.74%
# 20190201    19,167,472,059*    $143,454,405  -0.17%   1.20%  -17.74%
# 20190201         17,597,861     $66,405,205  -0.24%   0.27%  -14.07%

# %%
dictdf = df.to_dict(orient='records')

# %%
dictdf[:10]
# Out:
# [{'#': '1',
#   'Name': 'BTCBitcoin',
#   'Symbol': 'BTC',
#   'MktCap': '67796965743',
#   'Price': '$3859.58',
#   'Circulating Supply': '17,565,875',
#   'Volume (24h)': '$7,661,247,975',
#   '% 1h': '-0.62%',
#   '% 24h': '0.12%',
#   '% 7d': '-3.34%'},
#  {'#': '2',
#   'Name': 'ETHEthereum',
#   'Symbol': 'ETH',
#   'MktCap': '14335957425',
#   'Price': '$136.44',
#   'Circulating Supply': '105,068,725',
#   'Volume (24h)': '$3,756,124,824',
#   '% 1h': '-0.81%',
#   '% 24h': '-0.36%',
#   '% 7d': '-8.13%'},
#  {'#': '3',
#   'Name': 'XRPXRP',
#   'Symbol': 'XRP',
#   'MktCap': '13146898194',
#   'Price': '$0.317312',
#   'Circulating Supply': '41,432,141,931*',
#   'Volume (24h)': '$752,723,591',
#   '% 1h': '-0.95%',
#   '% 24h': '0.71%',
#   '% 7d': '-1.19%'},
#  {'#': '4',
#   'Name': 'EOSEOS',
#   'Symbol': 'EOS',
#   'MktCap': '3186278436',
#   'Price': '$3.52',
#   'Circulating Supply': '906,245,118*',
#   'Volume (24h)': '$1,318,189,790',
#   '% 1h': '-3.77%',
#   '% 24h': '-0.84%',
#   '% 7d': '-9.17%'},
#  {'#': '5',
#   'Name': 'LTCLitecoin',
#   'Symbol': 'LTC',
#   'MktCap': '2882042603',
#   'Price': '$47.49',
#   'Circulating Supply': '60,690,886',
#   'Volume (24h)': '$1,175,425,172',
#   '% 1h': '-1.75%',
#   '% 24h': '2.48%',
#   '% 7d': '-4.07%'},
#  {'#': '6',
#   'Name': 'BCHBitcoin Cash',
#   'Symbol': 'BCH',
#   'MktCap': '2346655915',
#   'Price': '$132.96',
#   'Circulating Supply': '17,649,100',
#   'Volume (24h)': '$240,782,300',
#   '% 1h': '-0.64%',
#   '% 24h': '0.71%',
#   '% 7d': '-7.81%'},
#  {'#': '7',
#   'Name': 'USDTTether',
#   'Symbol': 'USDT',
#   'MktCap': '2035341543',
#   'Price': '$1.01',
#   'Circulating Supply': '2,021,459,017*',
#   'Volume (24h)': '$6,628,411,253',
#   '% 1h': '-0.59%',
#   '% 24h': '-0.24%',
#   '% 7d': '-0.06%'},
#  {'#': '8',
#   'Name': 'XLMStellar',
#   'Symbol': 'XLM',
#   'MktCap': '1649050087',
#   'Price': '$0.085833',
#   'Circulating Supply': '19,212,285,395*',
#   'Volume (24h)': '$115,886,661',
#   '% 1h': '-1.08%',
#   '% 24h': '0.20%',
#   '% 7d': '-5.39%'},
#  {'#': '9',
#   'Name': 'BNBBinance Coin',
#   'Symbol': 'BNB',
#   'MktCap': '1608442973',
#   'Price': '$11.39',
#   'Circulating Supply': '141,175,490*',
#   'Volume (24h)': '$117,838,677',
#   '% 1h': '-1.45%',
#   '% 24h': '10.03%',
#   '% 7d': '5.96%'},
#  {'#': '10',
#   'Name': 'TRXTRON',
#   'Symbol': 'TRX',
#   'MktCap': '1582095415',
#   'Price': '$0.023726',
#   'Circulating Supply': '66,682,072,191',
#   'Volume (24h)': '$128,326,437',
#   '% 1h': '-0.82%',
#   '% 24h': '-0.61%',
#   '% 7d': '-5.43%'}]
